# %% [markdown]
# ####  IV sweep Timescan monitor
#
# Monitor plot updates automatically at a user-specified interval.
#
# RLH 1/1/2022

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import pandas as pd

# %%
# %matplotlib notebook

# %%
def animate_timescan(i, filename):
    ts_df = pd.read_csv(filename)
    time = ts_df["Elapsed Time"]
    efficiency = ts_df["PCE(%)"]
    ax1.clear()
    ax1.plot(time/60.0, efficiency, 'o')
    plt.xlabel("Time (hours)")
    plt.ylabel("PCE (%)")

# %%
path = r"C:\Users\LabUser\Documents\randy\Data_032022"
filename = "timeseries_parameters_010222"

# %%
# Run this code to start the animation
# Make sure you have the correct  path and filename!
update_interval = 5000  # units of ms.

fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

ani = animation.FuncAnimation(fig, animate_timescan, interval=update_interval, fargs = [path + "\\" + filename])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#ani.pause()

# %%
#ani.resume()

# %%
ts_df = pd.read_csv(path + "\\" + filename)
print(ts_df)
# Out:
#     Elapsed Time       Sample_Cell#   V_oc(V)   J_sc(mA)       R_sh  \
# 0      99.867829  Silicon_1F_150534  0.561205  33.672387  70.289273
# 1      99.867972  Silicon_1R_150534  0.583875  33.898125  80.832150
# 2     101.420410  Silicon_1F_150707  0.561329  33.749362  73.493446
# 3     101.420771  Silicon_1R_150707  0.584026  33.936413  82.585412
# 4     102.972341  Silicon_1F_150840  0.561198  33.799125  74.676598
# 5     102.972487  Silicon_1R_150840  0.584002  33.968288  84.265547
# 6     104.522884  Silicon_1F_151013  0.561250  33.830175  76.421681
# 7     104.522884  Silicon_1R_151013  0.583973  33.999812  85.888461
# 8     106.074106  Silicon_1F_151146  0.561177  33.865300  77.963055
# 9     106.074177  Silicon_1R_151146  0.583829  34.018325  87.247838
# 10    107.625131  Silicon_1F_151319  0.561034  33.869763  77.165829
# 11    107.625165  Silicon_1R_151319  0.583563  34.051188  89.184766
# 12    109.175087  Silicon_1F_151452  0.560983  33.896088  79.790764
# ...
